# %% [markdown]
# Loading in Data

# %%
import pandas as pd
import numpy as np
from pybaseball import *
import matplotlib.pylab as plt
import plotly.plotly as py
# %matplotlib inline

fangraph2012 = pd.read_csv("../fangraphs/2012.csv")
fangraph2013 = pd.read_csv("../fangraphs/2013.csv")
fangraph2014 = pd.read_csv("../fangraphs/2014.csv")
fangraph2015 = pd.read_csv("../fangraphs/2015.csv")
fangraph2016 = pd.read_csv("../fangraphs/2016.csv")
fangraph2017 = pd.read_csv("../fangraphs/2017.csv")
fangraph2018 = pd.read_csv("../fangraphs/2018.csv")

# %%
cano2012 = fangraph2012.loc[(fangraph2012['Name'] == 'Robinson Cano')].copy()
cano2013 = fangraph2013.loc[(fangraph2013['Name'] == 'Robinson Cano')].copy()
cano2014 = fangraph2014.loc[(fangraph2014['Name'] == 'Robinson Cano')].copy()
cano2015 = fangraph2015.loc[(fangraph2015['Name'] == 'Robinson Cano')].copy()
cano2016 = fangraph2016.loc[(fangraph2016['Name'] == 'Robinson Cano')].copy()
cano2017 = fangraph2017.loc[(fangraph2017['Name'] == 'Robinson Cano')].copy()
cano2018 = fangraph2018.loc[(fangraph2018['Name'] == 'Robinson Cano')].copy()
cano2012['year'] = 2012
# cano2012['points'] = 40.78
cano2013['year'] = 2013
cano2014['year'] = 2014
cano2015['year'] = 2015
cano2016['year'] = 2016
cano2017['year'] = 2017
cano2018['year'] = 2018

cano = pd.concat([cano2012,cano2013,cano2014,cano2015,cano2016,cano2017,cano2018])
bat_cano = cano[['WAR','OBP','SLG','wOBA','AVG']]
bat_cano.reset_index(inplace=True)
bat_cano = bat_cano.drop('index',axis=1)



cano_bat12 = bat_cano.loc[0,:].tolist()
cano_bat13 = bat_cano.loc[1,:].tolist()
cano_bat14 = bat_cano.loc[2,:].tolist()
cano_bat15 = bat_cano.loc[3,:].tolist()
cano_bat16 = bat_cano.loc[4,:].tolist()
cano_bat17 = bat_cano.loc[5,:].tolist()
cano_bat18 = bat_cano.loc[6,:].tolist()
cano_year_list = [cano_bat12, cano_bat13, cano_bat14, cano_bat15, cano_bat16, cano_bat17, cano_bat18]

# %%
shin2012 = fangraph2012.loc[(fangraph2012['Name'] == 'Shin-Soo Choo')].copy()
shin2013 = fangraph2013.loc[(fangraph2013['Name'] == 'Shin-Soo Choo')].copy()
shin2014 = fangraph2014.loc[(fangraph2014['Name'] == 'Shin-Soo Choo')].copy()
shin2015 = fangraph2015.loc[(fangraph2015['Name'] == 'Shin-Soo Choo')].copy()
shin2016 = fangraph2016.loc[(fangraph2016['Name'] == 'Shin-Soo Choo')].copy()
shin2017 = fangraph2017.loc[(fangraph2017['Name'] == 'Shin-Soo Choo')].copy()
shin2018 = fangraph2018.loc[(fangraph2018['Name'] == 'Shin-Soo Choo')].copy()
shin2012['year'] = 2012
shin2013['year'] = 2013
shin2014['year'] = 2014
shin2015['year'] = 2015
shin2016['year'] = 2016
shin2017['year'] = 2017
shin2018['year'] = 2018

shin = pd.concat([shin2012,shin2013,shin2014,shin2015,shin2016,shin2017,shin2018])
bat_shin = shin[['WAR','OBP','SLG','wOBA','AVG']]
bat_shin.reset_index(inplace=True)
bat_shin = bat_shin.drop('index',axis=1)
shin_bat12 = bat_shin.loc[0,:].tolist()
shin_bat13 = bat_shin.loc[1,:].tolist()
shin_bat14 = bat_shin.loc[2,:].tolist()
shin_bat15 = bat_shin.loc[3,:].tolist()
shin_bat16 = bat_shin.loc[4,:].tolist()
shin_bat17 = bat_shin.loc[5,:].tolist()
shin_bat18 = bat_shin.loc[6,:].tolist()
shin_year_list = [shin_bat12, shin_bat13, shin_bat14, shin_bat15, shin_bat16, shin_bat17, shin_bat18]

# %%
jacoby2012 = fangraph2012.loc[(fangraph2012['Name'] == 'Jacoby Ellsbury')].copy()
jacoby2013 = fangraph2013.loc[(fangraph2013['Name'] == 'Jacoby Ellsbury')].copy()
jacoby2014 = fangraph2014.loc[(fangraph2014['Name'] == 'Jacoby Ellsbury')].copy()
jacoby2015 = fangraph2015.loc[(fangraph2015['Name'] == 'Jacoby Ellsbury')].copy()
jacoby2016 = fangraph2016.loc[(fangraph2016['Name'] == 'Jacoby Ellsbury')].copy()
jacoby2017 = fangraph2017.loc[(fangraph2017['Name'] == 'Jacoby Ellsbury')].copy()
jacoby2018 = fangraph2018.loc[(fangraph2018['Name'] == 'Jacoby Ellsbury')].copy()
jacoby2012['year'] = 2012
jacoby2013['year'] = 2013
jacoby2014['year'] = 2014
jacoby2015['year'] = 2015
jacoby2016['year'] = 2016
jacoby2017['year'] = 2017
jacoby2018['year'] = 2018

jacoby = pd.concat([jacoby2012,jacoby2013,jacoby2014,jacoby2015,jacoby2016,jacoby2017,jacoby2018])
bat_jacoby = jacoby[['WAR','OBP','SLG','wOBA','AVG']]
bat_jacoby.reset_index(inplace=True)
bat_jacoby = bat_jacoby.drop('index',axis=1)
jacoby_bat12 = bat_jacoby.loc[0,:].tolist()
jacoby_bat13 = bat_jacoby.loc[1,:].tolist()
jacoby_bat14 = bat_jacoby.loc[2,:].tolist()
jacoby_bat15 = bat_jacoby.loc[3,:].tolist() 
jacoby_bat16 = bat_jacoby.loc[4,:].tolist()
jacoby_bat17 = bat_jacoby.loc[5,:].tolist()
# jacoby_bat18 = bat_jacoby.loc[6,:].tolist()
jacoby_year_list = [jacoby_bat12, jacoby_bat13, jacoby_bat14, jacoby_bat15, jacoby_bat16, jacoby_bat17]

# %%
upton2012 = fangraph2012.loc[(fangraph2012['Name'] == 'Melvin Upton Jr.')].copy()
upton2013 = fangraph2013.loc[(fangraph2013['Name'] == 'Melvin Upton Jr.')].copy()
upton2014 = fangraph2014.loc[(fangraph2014['Name'] == 'Melvin Upton Jr.')].copy()
upton2015 = fangraph2015.loc[(fangraph2015['Name'] == 'Melvin Upton Jr.')].copy()
upton2016 = fangraph2016.loc[(fangraph2016['Name'] == 'Melvin Upton Jr.')].copy()
upton2017 = fangraph2017.loc[(fangraph2017['Name'] == 'Melvin Upton Jr.')].copy()
upton2018 = fangraph2018.loc[(fangraph2018['Name'] == 'Melvin Upton Jr.')].copy()
upton2012['year'] = 2012
upton2013['year'] = 2013
upton2014['year'] = 2014
upton2015['year'] = 2015
upton2016['year'] = 2016
upton2017['year'] = 2017
upton2018['year'] = 2018

upton = pd.concat([upton2012,upton2013,upton2014,upton2015,upton2016,upton2017,upton2018])
bat_upton = upton[['WAR','OBP','SLG','wOBA','AVG']]
bat_upton.reset_index(inplace=True)
bat_upton = bat_upton.drop('index',axis=1)
upton_bat12 = bat_upton.loc[0,:].tolist()
upton_bat13 = bat_upton.loc[1,:].tolist()
upton_bat14 = bat_upton.loc[2,:].tolist()
upton_bat15 = bat_upton.loc[3,:].tolist() 
upton_bat16 = bat_upton.loc[4,:].tolist()
# upton_bat17 = bat_upton.loc[5,:].tolist()
# upton_bat18 = bat_upton.loc[6,:].tolist()
upton_year_list = [upton_bat12, upton_bat13, upton_bat14, upton_bat15, upton_bat16]

# %%
brian2012 = fangraph2012.loc[(fangraph2012['Name'] == 'Brian McCann')].copy()
brian2013 = fangraph2013.loc[(fangraph2013['Name'] == 'Brian McCann')].copy()
brian2014 = fangraph2014.loc[(fangraph2014['Name'] == 'Brian McCann')].copy()
brian2015 = fangraph2015.loc[(fangraph2015['Name'] == 'Brian McCann')].copy()
brian2016 = fangraph2016.loc[(fangraph2016['Name'] == 'Brian McCann')].copy()
brian2017 = fangraph2017.loc[(fangraph2017['Name'] == 'Brian McCann')].copy()
brian2018 = fangraph2018.loc[(fangraph2018['Name'] == 'Brian McCann')].copy()
brian2012['year'] = 2012
brian2013['year'] = 2013
brian2014['year'] = 2014
brian2015['year'] = 2015
brian2016['year'] = 2016
brian2017['year'] = 2017
brian2018['year'] = 2018

brian = pd.concat([brian2012,brian2013,brian2014,brian2015,brian2016,brian2017,brian2018])
bat_brian = brian[['WAR','OBP','SLG','wOBA','AVG']]
bat_brian.reset_index(inplace=True)
bat_brian = bat_brian.drop('index',axis=1)
brian_bat12 = bat_brian.loc[0,:].tolist()
brian_bat13 = bat_brian.loc[1,:].tolist()
brian_bat14 = bat_brian.loc[2,:].tolist()
brian_bat15 = bat_brian.loc[3,:].tolist() 
brian_bat16 = bat_brian.loc[4,:].tolist()
brian_bat17 = bat_brian.loc[5,:].tolist()
brian_bat18 = bat_brian.loc[6,:].tolist()
brian_year_list = [brian_bat12, brian_bat13, brian_bat14, brian_bat15, brian_bat16,brian_bat17,brian_bat18]

# %%
from pybaseball import *
salary = salaries()
sal12 = salary.loc[(salary['yearID'] == 2012)]
sal13 = salary.loc[(salary['yearID'] == 2013)]
sal14 = salary.loc[(salary['yearID'] == 2014)]
sal15 = salary.loc[(salary['yearID'] == 2015)]
sal16 = salary.loc[(salary['yearID'] == 2016)]
sal17 = salary.loc[(salary['yearID'] == 2017)]
sal18 = salary.loc[(salary['yearID'] == 2018)]
 
sal_mean12 = sal12['salary'].mean()
sal_mean13 = sal13['salary'].mean()
sal_mean14 = sal14['salary'].mean()
sal_mean15 = sal15['salary'].mean()
sal_mean16 = sal16['salary'].mean()
sal_mean17 = 4470000
sal_mean18 = 4520000

# %%
from pybaseball import *
# salary.loc[(salary['yearID'] >= 2012)]
master = master()
fullsalary = pd.merge(master[['playerID','nameFirst','nameLast']], salary, on = ['playerID'],how='inner')
j_salary_real = fullsalary.loc[(fullsalary['nameFirst'] == 'Jacoby') & (fullsalary['nameLast'] == 'Ellsbury') & (fullsalary['yearID'] >=2012)]
shin_salary_real = fullsalary.loc[(fullsalary['nameFirst'] == 'Shin-Soo') & (fullsalary['nameLast'] == 'Choo') & (fullsalary['yearID'] >=2012)]
upton_salary_real = fullsalary.loc[(fullsalary['nameFirst'] == 'Melvin') & (fullsalary['nameLast'] == 'Upton') & (fullsalary['yearID'] >=2012)]
brian_salary_real = fullsalary.loc[(fullsalary['nameFirst'] == 'Brian') & (fullsalary['nameLast'] == 'McCann') & (fullsalary['yearID'] >=2012)]
cano_salary_real = fullsalary.loc[(fullsalary['nameFirst'] == 'Robinson') & (fullsalary['nameLast'] == 'Cano') & (fullsalary['yearID'] >=2012)]

j_salary_real = j_salary_real['salary'].tolist()
shin_salary_real = shin_salary_real['salary'].tolist()
upton_salary_real = upton_salary_real['salary'].tolist()
brian_salary_real = brian_salary_real['salary'].tolist()
cano_salary_real = cano_salary_real['salary'].tolist()

cano_salary_real.append(24000000) 
cano_salary_real.append(13667440)
brian_salary_real.append(5500000)
brian_salary_real.append(11500000)
upton_salary_real.append(16450000)
shin_salary_real.append(20000000)
shin_salary_real.append(20000000)
j_salary_real.append(21142857)
j_salary_real.append(21142857)

# %%
year12 = fangraph2012.loc[(fangraph2012['AVG'] !=0) & (fangraph2012['OBP'] !=0) & (fangraph2012['SLG'] !=0) & (fangraph2012['wOBA'] !=0)]
year13 = fangraph2013.loc[(fangraph2013['AVG'] !=0) & (fangraph2013['OBP'] !=0) & (fangraph2013['SLG'] !=0) & (fangraph2013['wOBA'] !=0)]
year14 = fangraph2014.loc[(fangraph2014['AVG'] !=0) & (fangraph2014['OBP'] !=0) & (fangraph2014['SLG'] !=0) & (fangraph2014['wOBA'] !=0)]
year15 = fangraph2015.loc[(fangraph2015['AVG'] !=0) & (fangraph2015['OBP'] !=0) & (fangraph2015['SLG'] !=0) & (fangraph2015['wOBA'] !=0)]
year16 = fangraph2016.loc[(fangraph2016['AVG'] !=0) & (fangraph2016['OBP'] !=0) & (fangraph2016['SLG'] !=0) & (fangraph2016['wOBA'] !=0)]
year17 = fangraph2017.loc[(fangraph2017['AVG'] !=0) & (fangraph2017['OBP'] !=0) & (fangraph2017['SLG'] !=0) & (fangraph2017['wOBA'] !=0)]
year18 = fangraph2018.loc[(fangraph2018['AVG'] !=0) & (fangraph2018['OBP'] !=0) & (fangraph2018['SLG'] !=0) & (fangraph2018['wOBA'] !=0)]

# %%
twelve_avg = year12['AVG'].tolist()
twelve_obp = year12['OBP'].tolist()
twelve_woba = year12['wOBA'].tolist()
twelve_slg = year12['SLG'].tolist()
war_2012 = year12['WAR'].tolist()
war_mean12 = np.mean(war_2012)
woba_mean12 = np.mean(twelve_woba)
slg_mean12 = np.mean(twelve_slg)
obp_mean12 = np.mean(twelve_obp)
ba_mean12 = np.mean(twelve_avg)

#####
thirteen_avg = year13['AVG'].tolist()
thirteen_obp = year13['OBP'].tolist()
thirteen_woba = year13['wOBA'].tolist()
thirteen_slg = year13['SLG'].tolist()
war_2013 = year13['WAR'].tolist()
war_mean13 = np.mean(war_2013)
woba_mean13 = np.mean(thirteen_woba)
slg_mean13 = np.mean(thirteen_slg)
obp_mean13 = np.mean(thirteen_obp)
ba_mean13 = np.mean(thirteen_avg)

#####

fourteen_avg = year14['AVG'].tolist()
fourteen_obp = year14['OBP'].tolist()
fourteen_woba = year14['wOBA'].tolist()
fourteen_slg = year14['SLG'].tolist()
war_2014 = year14['WAR'].tolist()
war_mean14 = np.mean(war_2014)
woba_mean14 = np.mean(fourteen_woba)
slg_mean14 = np.mean(fourteen_slg)
obp_mean14 = np.mean(fourteen_obp)
ba_mean14 = np.mean(fourteen_avg)

#####
fifteen_avg = year15['AVG'].tolist()
fifteen_obp = year15['OBP'].tolist()
fifteen_woba = year15['wOBA'].tolist()
fifteen_slg = year15['SLG'].tolist()
war_2015 = year15['WAR'].tolist()
war_mean15 = np.mean(war_2015)
woba_mean15 = np.mean(fifteen_woba)
slg_mean15 = np.mean(fifteen_slg)
obp_mean15 = np.mean(fifteen_obp)
ba_mean15 = np.mean(fifteen_avg)


#####
sixteen_avg = year16['AVG'].tolist()
sixteen_obp = year16['OBP'].tolist()
sixteen_woba = year16['wOBA'].tolist()
sixteen_slg = year16['SLG'].tolist()
war_2016 = year16['WAR'].tolist()
war_mean16 = np.mean(war_2016)
woba_mean16 = np.mean(sixteen_woba)
slg_mean16 = np.mean(sixteen_slg)
obp_mean16 = np.mean(sixteen_obp)
ba_mean16 = np.mean(sixteen_avg)

#####
seventeen_avg = year17['AVG'].tolist()
seventeen_obp = year17['OBP'].tolist()
seventeen_woba = year17['wOBA'].tolist()
seventeen_slg = year17['SLG'].tolist()
war_2017 = year17['WAR'].tolist()
war_mean17 = np.mean(war_2017)
woba_mean17 = np.mean(seventeen_woba)
slg_mean17 = np.mean(seventeen_slg)
obp_mean17 = np.mean(seventeen_obp)
ba_mean17 = np.mean(seventeen_avg)

#####

eighteen_avg = year18['AVG'].tolist()
eighteen_obp = year18['OBP'].tolist()
eighteen_woba = year18['wOBA'].tolist()
eighteen_slg = year18['SLG'].tolist()
war_2018 = year18['WAR'].tolist()
war_mean18 = np.mean(war_2018)
woba_mean18 = np.mean(eighteen_woba)
slg_mean18 = np.mean(eighteen_slg)
obp_mean18 = np.mean(eighteen_obp)
ba_mean18 = np.mean(eighteen_avg)

#####
overall_avg12 = war_mean12,obp_mean12,slg_mean12,woba_mean12, ba_mean12
overall_avg13 = war_mean13,obp_mean13,slg_mean13,woba_mean13, ba_mean13
overall_avg14 = war_mean14,obp_mean14,slg_mean14,woba_mean14, ba_mean14
overall_avg15 = war_mean15,obp_mean15,slg_mean15,woba_mean15, ba_mean15
overall_avg16 = war_mean16,obp_mean16,slg_mean16,woba_mean16, ba_mean16
overall_avg17 = war_mean17,obp_mean17,slg_mean17,woba_mean17, ba_mean17
overall_avg18 = war_mean18,obp_mean18,slg_mean18,woba_mean18, ba_mean18

overall_list = [overall_avg12 ,overall_avg13 ,overall_avg14,overall_avg15 ,overall_avg16,overall_avg17,overall_avg18]
salary_list = [sal_mean12,sal_mean13,sal_mean14,sal_mean15,sal_mean16,sal_mean17,sal_mean18]

# %% [markdown]
# ## Player point algorithm

# %% [markdown]
# ### Cano

# %%
my_cano_salaries = []
my_cano_total_points = []


for (i,j,z) in zip(cano_year_list,overall_list,salary_list):
    a = np.array(i, dtype=np.float)
    b = np.array(j, dtype=np.float)
    check = a/b
    check[0] = check[0]*4
    total_points = check.sum()
    point_worth = z/8 ## 8 is the amount of points your average player gets 
    salaries = point_worth * total_points
    my_cano_total_points.append(total_points)
    my_cano_salaries.append(salaries)
    
bat_cano['points'] = my_cano_total_points
bat_cano['my_salary'] = my_cano_salaries

# %% [markdown]
# ### Shin

# %%
my_shin_salaries = []
my_shin_total_points = []


for (i,j,z) in zip(shin_year_list,overall_list,salary_list):
    a = np.array(i, dtype=np.float)
    b = np.array(j, dtype=np.float)
    check = a/b
    check[0] = check[0]*4
    total_points = check.sum()
    point_worth = z/8 ## 8 is the amount of points your average player gets 
    salaries = point_worth * total_points
    my_shin_total_points.append(total_points)
    my_shin_salaries.append(salaries)
    
bat_shin['points'] = my_shin_total_points
bat_shin['my_salary'] = my_shin_salaries

# %% [markdown]
# ### Jacoby

# %%
my_jacoby_salaries = []
my_jacoby_total_points = []


for (i,j,z) in zip(jacoby_year_list,overall_list,salary_list):
    a = np.array(i, dtype=np.float)
    b = np.array(j, dtype=np.float)
    check = a/b
    check[0] = check[0]*4
    total_points = check.sum()
    point_worth = z/8 ## 8 is the amount of points your average player gets 
    salaries = point_worth * total_points
    my_jacoby_total_points.append(total_points)
    my_jacoby_salaries.append(salaries)
    
bat_jacoby['points'] = my_jacoby_total_points
bat_jacoby['my_salary'] = my_jacoby_salaries

# %% [markdown]
# ### Upton

# %%
my_upton_salaries = []
my_upton_total_points = []


for (i,j,z) in zip(upton_year_list,overall_list,salary_list):
    a = np.array(i, dtype=np.float)
    b = np.array(j, dtype=np.float)
    check = a/b
    check[0] = check[0]*4
    total_points = check.sum()
    point_worth = z/8 ## 8 is the amount of points your average player gets 
    salaries = point_worth * total_points
    my_upton_total_points.append(total_points)
    my_upton_salaries.append(salaries)
    
bat_upton['points'] = my_upton_total_points
bat_upton['my_salary'] = my_upton_salaries

# %% [markdown]
# ## McCan

# %%
my_brian_salaries = []
my_brian_total_points = []


for (i,j,z) in zip(brian_year_list,overall_list,salary_list):
    a = np.array(i, dtype=np.float)
    b = np.array(j, dtype=np.float)
    check = a/b
    check[0] = check[0]*4
    total_points = check.sum()
    point_worth = z/8 ## 8 is the amount of points your average player gets 
    salaries = point_worth * total_points
    my_brian_total_points.append(total_points)
    my_brian_salaries.append(salaries)
    
bat_brian['points'] = my_brian_total_points
bat_brian['my_salary'] = my_brian_salaries

# %% [markdown]
# # Fibonacci Retracement (Replacement Level)
# #### Players performace over years to see where team begins to lose money

# %% [markdown]
# ## Cano Fibonacci Retracement

# %%
m = bat_cano['points'].max()
half_line_cano = m*0.5
cano_38_line = m*0.382
cano_23_line = m*0.236
cano_61 = m*0.618
cano_78 = m* 0.786
#############
fig, ax = plt.subplots()
plt.plot(my_cano_total_points, marker='o', markerfacecolor='blue', markersize=12, color='black', linewidth=4)
plt.hlines(half_line_cano,0,7, color = 'green',label = 'half-line')
plt.hlines(cano_38_line,0,7,color = 'red',label = '38.2% line')
plt.hlines(cano_23_line,0,7, color = 'black',label = '23.6% line')
plt.hlines(cano_61,0,7, color = 'yellow',label = '61.8% line')
plt.hlines(cano_78,0,7, color = 'blue', label = '78.6% line')


# ax.axhspan(half_line_cano, lowish, alpha=0.4, color='salmon')
# ax.axhspan(cano_38_line, low_line, alpha=0.5, color='salmon')
# ax.axhspan(cano_61, half, alpha=0.5, color='salmon')
# ax.axhspan(cano_78, sixtyone, alpha=0.5, color='palegreen')
plt.xticks(np.arange(0,8,step=1), (2012,2013,2014,2015,2016,2017,2018))
plt.xlabel('Years')
plt.ylabel('Points')
plt.title("Years vs. Points")
# ax.set_facecolor('xkcd:black')
plt.legend()
fig.set_size_inches(10, 5)
plt.show()

plt.plot(cano_salary_real, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot(salary_list, marker='o', markerfacecolor='green', markersize=12, color='black', linewidth=4)
plt.xlabel('Years')
plt.ylabel('Salary')
plt.title("MLB Average Salary vs. Player Salary")
plt.show()

# %% [markdown]
# ## Shin Fibonacci Retracement

# %%
m = bat_shin['points'].max()
half_line_shin = m*0.5
shin_38_line = m*0.382
shin_23_line = m*0.236
shin_61 = m*0.618
shin_78 = m* 0.786
#############
fig, ax = plt.subplots()
plt.plot(my_shin_total_points, marker='o', markerfacecolor='blue', markersize=12, color='black', linewidth=4)
plt.hlines(half_line_shin,0,7, color = 'green',label = 'half-line')
plt.hlines(shin_38_line,0,7,color = 'red',label = '38.2% line')
plt.hlines(shin_23_line,0,7, color = 'black',label = '23.6% line')
plt.hlines(shin_61,0,7, color = 'yellow',label = '61.8% line')
plt.hlines(shin_78,0,7, color = 'blue', label = '78.6% line')


# ax.axhspan(half_line_shin, lowish, alpha=0.4, color='powderblue')
# ax.axhspan(shin_38_line, low_line, alpha=0.5, color='salmon')
# ax.axhspan(shin_61, half, alpha=0.5, color='orange')
# ax.axhspan(shin_78, sixtyone, alpha=0.5, color='palegreen')
plt.xticks(np.arange(0,8,step=1), (2012,2013,2014,2015,2016,2017,2018))
# ax.set_facecolor('xkcd: color')
plt.legend()
plt.xlabel('Years')
plt.ylabel('Points')
plt.title("Years vs. Points")
fig.set_size_inches(10, 5)
plt.show()

plt.plot(shin_salary_real, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot(salary_list, marker='o', markerfacecolor='green', markersize=12, color='black', linewidth=4)
plt.xlabel('Years')
plt.ylabel('Salary')
plt.title("MLB Average Salary vs. Player Salary")
plt.show()

# %% [markdown]
# ## Jacoby Fibonacci Retracement

# %%
m = bat_jacoby['points'].max()
half_line_jacoby = m*0.5
jacoby_38_line = m*0.382
jacoby_23_line = m*0.236
jacoby_61 = m*0.618
jacoby_78 = m* 0.786
#############
fig, ax = plt.subplots()
plt.plot(my_jacoby_total_points, marker='o', markerfacecolor='blue', markersize=12, color='black', linewidth=4)
plt.hlines(half_line_jacoby,0,7, color = 'green',label = 'half-line')
plt.hlines(jacoby_38_line,0,7,color = 'red',label = '38.2% line')
plt.hlines(jacoby_23_line,0,7, color = 'black',label = '23.6% line')
plt.hlines(jacoby_61,0,7, color = 'yellow',label = '61.8% line')
plt.hlines(jacoby_78,0,7, color = 'blue', label = '78.6% line')


# ax.axhspan(half_line_jacoby, lowish, alpha=0.4, color='powderblue')
# ax.axhspan(jacoby_38_line, low_line, alpha=0.5, color='salmon')
# ax.axhspan(jacoby_61, half, alpha=0.5, color='orange')
# ax.axhspan(jacoby_78, sixtyone, alpha=0.5, color='palegreen')
plt.xticks(np.arange(0,8,step=1), (2012,2013,2014,2015,2016,2017,2018))
# ax.set_facecolor('xkcd: color')
plt.xlabel('Years')
plt.ylabel('Points')
plt.title("Years vs. Points")
plt.legend()
fig.set_size_inches(10, 5)
plt.show()

plt.plot(j_salary_real, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot(salary_list, marker='o', markerfacecolor='green', markersize=12, color='black', linewidth=4)
plt.xlabel('Years')
plt.ylabel('Salary')
plt.title("MLB Average Salary vs. Player Salary")
plt.show()

# %% [markdown]
# ### Upton Fibonacci Retracement

# %%
m = bat_upton['points'].max()
half_line_upton = m*0.5
upton_38_line = m*0.382
upton_23_line = m*0.236
upton_61 = m*0.618
upton_78 = m* 0.786
#############
fig, ax = plt.subplots()
plt.plot(my_upton_total_points, marker='o', markerfacecolor='blue', markersize=12, color='black', linewidth=4)
plt.hlines(half_line_upton,0,7, color = 'green',label = 'half-line')
plt.hlines(upton_38_line,0,7,color = 'red',label = '38.2% line')
plt.hlines(upton_23_line,0,7, color = 'black',label = '23.6% line')
plt.hlines(upton_61,0,7, color = 'yellow',label = '61.8% line')
plt.hlines(upton_78,0,7, color = 'blue', label = '78.6% line')


# ax.axhspan(half_line_upton, lowish, alpha=0.4, color='powderblue')
# ax.axhspan(upton_38_line, low_line, alpha=0.5, color='salmon')
# ax.axhspan(upton_61, half, alpha=0.5, color='orange')
# ax.axhspan(upton_78, sixtyone, alpha=0.5, color='palegreen')
plt.xticks(np.arange(0,8,step=1), (2012,2013,2014,2015,2016,2017,2018))
# ax.set_facecolor('xkcd: color')
plt.xlabel('Years')
plt.ylabel('Points')
plt.title("Years vs. Points")
plt.legend()
fig.set_size_inches(10, 5)
plt.show()

plt.plot(upton_salary_real, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot(salary_list, marker='o', markerfacecolor='green', markersize=12, color='black', linewidth=4)
plt.xlabel('Years')
plt.ylabel('Salary')
plt.title("MLB Average Salary vs. Player Salary")
plt.show()

# %% [markdown]
# ### Brian McCan Fiboncacci Retracement

# %%
m = bat_brian['points'].max()
half_line_brian = m*0.5
brian_38_line = m*0.382
brian_23_line = m*0.236
brian_61 = m*0.618
brian_78 = m* 0.786
#############
fig, ax = plt.subplots()
plt.plot(my_brian_total_points, marker='o', markerfacecolor='blue', markersize=12, color='black', linewidth=4)
plt.hlines(half_line_brian,0,7, color = 'green',label = 'half-line')
plt.hlines(brian_38_line,0,7,color = 'red',label = '38.2% line')
plt.hlines(brian_23_line,0,7, color = 'black',label = '23.6% line')
plt.hlines(brian_61,0,7, color = 'yellow',label = '61.8% line')
plt.hlines(brian_78,0,7, color = 'blue', label = '78.6% line')


# ax.axhspan(half_line_brian, lowish, alpha=0.4, color='salmon')
# ax.axhspan(brian_38_line, low_line, alpha=0.5, color='salmon')
# ax.axhspan(brian_61, half, alpha=0.5, color='salmon')
# ax.axhspan(brian_78, sixtyone, alpha=0.5, color='palegreen')
plt.xticks(np.arange(0,8,step=1), (2012,2013,2014,2015,2016,2017,2018))
# ax.set_facecolor('xkcd:black')
plt.legend()
plt.xlabel('Years')
plt.ylabel('Points')
plt.title("Years vs. Points")
fig.set_size_inches(10, 5)
plt.show()

plt.plot(brian_salary_real, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot(salary_list, marker='o', markerfacecolor='green', markersize=12, color='black', linewidth=4)
plt.xlabel('Years')
plt.ylabel('Salary')
plt.title("MLB Average Salary vs. Player Salary")
plt.show()

# %% [markdown]
# ### Stats Box Plot 2012-2018
# #### To help visualize point system

# %%
fig, ax1 = plt.subplots()
fig, ax2 = plt.subplots()
fig, ax3 = plt.subplots()
fig, ax4 = plt.subplots()
fig, ax5 = plt.subplots()
fig, ax6 = plt.subplots()
fig, ax7 = plt.subplots()
data12 = [twelve_avg,twelve_obp,twelve_slg,twelve_woba]
data13 = [thirteen_avg,thirteen_obp,thirteen_slg,thirteen_woba]
data14 = [fourteen_avg,fourteen_obp,fourteen_slg,fourteen_woba]
data15 = [fifteen_avg,fifteen_obp,fifteen_slg,fifteen_woba]
data16 = [sixteen_avg,sixteen_obp,sixteen_slg,sixteen_woba]
data17 = [seventeen_avg,seventeen_obp,seventeen_slg,seventeen_woba]
data18 =  [eighteen_avg,eighteen_obp,eighteen_slg,eighteen_woba]
for i in range(5):
    data = [i]
    ax1.boxplot(data12)
    ax2.boxplot(data13)
    ax3.boxplot(data14)
    ax4.boxplot(data15)
    ax5.boxplot(data16)
    ax6.boxplot(data17)
    ax7.boxplot(data18)
    marks = ['Batting Avg','OBP','SLG','w_OBA']
    ax1.set_xticklabels(marks)
    ax2.set_xticklabels(marks)
    ax3.set_xticklabels(marks)
    ax4.set_xticklabels(marks)
    ax5.set_xticklabels(marks)
    ax6.set_xticklabels(marks)
    ax7.set_xticklabels(marks)
    ax1.set_title("Stats 2012")
    ax2.set_title("Stats 2013")
    ax3.set_title("Stats 2014")
    ax4.set_title("Stats 2015")
    ax5.set_title("Stats 2016")
    ax6.set_title("Stats 2017")
    ax7.set_title("Stats 2018")
    ax1.set_ylabel('League Average')
    ax2.set_ylabel('League Average')
    ax3.set_ylabel('League Average')
    ax4.set_ylabel('League Average')
    ax5.set_ylabel('League Average')
    ax6.set_ylabel('League Average')
    ax7.set_ylabel('League Average')
    plt.show()
    

# fig, axs = plt.subplots()
# data = [war_2012]
# axs.boxplot(data)
# marks = ['WAR 2012']
# axs.set_xticklabels(marks)

plt.show()
